# %% [markdown]
# 1. What is hypothesis testing in statistics
#
#      - Hypothesis testing is a statistical method used to make inferences or draw conclusions about a population based on a sample of data. It involves formulating two competing hypotheses and using sample data to determine which hypothesis is more likely to be true.
#      - Types of Errors in Hypothesis Testing
#          - Type I Error (α)
#          - Type II Error (β)
#
# 2. What is the null hypothesis, and how does it differ from the alternative
#   hypothesis
#
#      - Null Hypothesis
#         - Assumes no change or effect
#         - To be tested and possibly rejected
#         - The average test score is 75
#
#   - Alternative Hypothesis
#      - Suggests a change or effect
#      - To be supported if evidence suggests
#      - The average test score is not 75.
#
# 3. What is the significance level in hypothesis testing, and why is it
#   important
#
#     - The significance level in hypothesis testing is the probability of rejecting the null hypothesis when it is actually true (Type I error). It represents the threshold for determining statistical significance.
#     - Common Significance Levels:
#        - 0.05 (5%) - Most commonly used
#        - 0.01 (1%) - More stringent, used in highly critical studies
#        - 0.10 (10%) - Sometimes used in exploratory research
#
# 4. What does a P-value represent in hypothesis testing
#
#    - The p-value is a fundamental concept in statistical inference that quantifies the probability of obtaining results at least as extreme as the observed data, assuming that the null hypothesis is true.
#    - The probability that 𝐻0 is true.
#    - The magnitude or practical significance of the effect.
#    - The probability of making an error directly.
#
# 5. How do you interpret the P-value in hypothesis testing
#
#    - Interpreting the P-Value in Hypothesis Testing
#    - The p-value represents the probability of obtaining a test statistic as extreme as, or more extreme than, the observed result if the null hypothesis (𝐻0) is true. It helps determine whether to reject 𝐻0in favor of the alternative hypothesis (𝐻a).
#
#
# 6. What are Type 1 and Type 2 errors in hypothesis testing
#
#    1. Type I Error (False Positive)
#        - Occurs when H0(null hypothesis) is true, but we reject it.
#        - Probability of Type I error = α (significance level)
#        - Example: A medical test wrongly detects a disease in a healthy person.
#
#   2. Type II Error (False Negative)
#       - Occurs when 𝐻0 is false, but we fail to reject it.
#       - Probability of Type II error = β.
#       - Example: A medical test fails to detect a disease in a sick person.
#
# 7. What is the difference between a one-tailed and a two-tailed test in
#   hypothesis testing
#
#     1. One-Tailed Test (Directional Test)
#        - Tests for an effect in one specific direction (greater or smaller).
#        - Only tests in one direction
#        - Uses one tail of the distribution
#        - Is the new drug better than the old one
#
#     2. Two-Tailed Test (Non-Directional Test)
#        - Tests for an effect in both directions (greater or smaller).
#        - Tests in both directions
#        - Splits p-value into two tails
#        - Is the new drug different from the old one
#
#
# 8. What is the Z-test, and when is it used in hypothesis testing
#
#     - Z-Test in Hypothesis Testing
#     - A Z-test is a statistical test used to determine whether there is a significant difference between sample and population means when the population variance is known and the sample size is large It follows a normal distribution (Z-distribution).
#     - When to Use a Z-Test?
#       - The sample size is large (n≥30).
#       - The population standard deviation (σ) is known.
#       - The data is normally distributed or approximately normal (Central Limit Theorem).
#
#
# 9. How do you calculate the Z-score, and what does it represent in hypothesis
#   testing
#
#      - Z-Score in Hypothesis Testing
#         - The Z-score (standard score) measures how many standard deviations a data point or sample mean is from the population mean. It helps determine whether to reject the null hypothesis (𝐻0) in a Z-test.
#     - Formula for Z-Score
#        - X = Data point
#        - μ = Population mean
#        - σ = Population standard deviation
#
# 10. What is the T-distribution, and when should it be used instead of the
#   normal distribution
#
#     - T-Distribution and When to Use It
#          - The T-distribution (Student's t-distribution) is a probability distribution used in hypothesis testing when the sample size is small and/or the population standard deviation (σ) is unknown.
#   - Example Situation:
#
#         - A researcher wants to test if the average study time of students is 5 hours per day. A sample of 15 students reports an average of 4.5 hours with a standard deviation of 1.2 hours.Since 𝑛=15 (small) and 𝜎is unknown, we use the T-distribution instead of the Z-distribution.
#
# 11. What is the difference between a Z-test and a T-test
#
#     - Z-Test
#         - Large sample (n≥30)
#         - Population Standard Deviation is known
#         - Normal (Z-distribution)
#         - Tail Behavior	Narrower tails
#
#    - T-Test
#         - Small sample (n<30)
#         - Population Standard Deviation is unknown
#         - T-distribution
#         - Tail Behavior Wider tails (to account for more variability)
#
#
# 12. What is the T-test, and how is it used in hypothesis testing
#
#     - T-Test in Hypothesis Testing
#     - A T-test is a statistical test used to compare the means of one or two groups when the population standard deviation (σ) is unknown and/or the sample size is small (n<30).
#     - It follows a T-distribution, which accounts for variability in small samples.
#     - Types of T-Tests:
#         - One-Sample T-Test → Compares a sample mean to a known population mean.
#         - Independent (Two-Sample) T-Test → Compares the means of two independent groups.
#         - Paired (Dependent) T-Test → Compares means of the same group before and after treatment.
#
# 13. Paired (Dependent) T-Test → Compares means of the same group before and
#    after treatment.
#
#     - Paired (Dependent) T-Test
#        - A Paired T-Test (also called a Dependent T-Test) is used to compare the means of the same group before and after an intervention or under two different conditions. It helps determine whether a significant difference exists between the two related measurements.
#     - When to Use a Paired T-Test?
#          - The same subjects are measured twice (before and after).
#          - The data is normally distributed (or approximately normal).
#          - The differences between paired observations are continuous and measured on an interval or ratio
#
#
# 14. What is a confidence interval, and how is it used to interpret statistical
#    results
#
#       - Confidence Interval (CI) in Statistics
#           - A confidence interval (CI) is a range of values used to estimate an unknown population parameter (e.g., mean or proportion) based on a sample. It provides an interval within which the true population parameter is likely to fall, with a specified level of confidence (e.g., 95% or 99%).
#
#       - Why Use Confidence Intervals?
#          - Provides a range instead of a single estimate.
#          - Helps assess the precision of the estimate (narrow CI = more precise).
#          - Useful for decision-making in research, business, and medicine
#
#
# 15. What is the margin of error, and how does it affect the confidence interval
#
#     - Margin of Error (MOE) and Its Effect on Confidence Interval :
#         - he Margin of Error (MOE) is the amount of uncertainty or potential error in an estimate when using a sample to infer about a population.
#         - It determines how much the sample statistic (e.g., sample mean) might differ from the true population parameter.
#         - Factors That Affect MOE
#            1. Confidence Level (α)
#            2. Sample Size (n)
#            3. Standard Deviation (σ)
#
#
# 16. How is Bayes' Theorem used in statistics, and what is its significance
#
#     - Bayes' Theorem in Statistics and Its Significance
#       - Bayes' Theorem describes how to update probabilities based on new evidence. It helps in revising prior beliefs when new data is available.
#     - How Is Bayes' Theorem Used in Statistics?
#        - Medical Diagnosis
#        - Spam Filtering
#        - Machine Learning & AI
#        - Legal System
#
#
# 17. What is the Chi-square distribution, and when is it used
#
#    - Chi-Square Distribution & Its Applications
#       - The Chi-Square (χ2) distribution is a probability distribution that arises in statistics when dealing with categorical data. It is used for testing relationships between categorical variables and analyzing variance in samples.
#   - Key Characteristics:
#      - Asymmetrical (skewed right) but becomes normal-shaped as degrees of freedom (df) increase.
#      - Only takes non-negative values (since it’s based on squared differences).
#      -  Defined by degrees of freedom (df), which determine its shape.
#
#
# 18. What is the Chi-square goodness of fit test, and how is it applied
#
#     - Chi-Square Goodness-of-Fit Test
#        - The Chi-Square Goodness-of-Fit Test checks whether an observed frequency distribution matches an expected distribution. It is used to determine if a sample data set fits a hypothesized distribution.
#
#     - When to Use It?
#        - The data is categorical (e.g., colors, brands, preferences).
#        - You want to compare observed frequencies to expected frequencies.
#        - The expected frequency for each category is at least 5 (to ensure statistical validity)
#
#
# 19. What is the F-distribution, and when is it used in hypothesis testing
#
#     - What Is the F-Distribution?
#       - The F-distribution is a continuous probability distribution that arises in statistics when comparing variances of two different groups. It is right-skewed and always non-negative because it is based on squared values.
#   - When Is the F-Distribution Used?
#
#       - Analysis of Variance (ANOVA)
#       - F-Test for Comparing Variances
#       - Regression Analysis
#
#
# 20. What is an ANOVA test, and what are its assumptions
#
#     - What Is an ANOVA Test?
#         - ANOVA (Analysis of Variance) is a statistical test used to determine whether three or more group means are significantly different from each other. It is an extension of the t-test (which compares two means).
#     - Types of ANOVA:
#
#          1.  One-Way ANOVA: Compares one independent variable with multiple groups.
#          2. Two-Way ANOVA: Examines the effect of two independent variables on one dependent variable.
#          3. Repeated Measures ANOVA: Used when the same subjects are tested multiple times under different conditions.
#
#
# 21. What are the different types of ANOVA tests
#
#     1. One-Way ANOVA
#     - Comparing one factor across multiple groups
#
#     2. Two-Way ANOVA
#     - Comparing two factors across groups
#
#     3. Repeated Measures ANOVA
#     - Testing the same subjects over time
#
#     4. MANOVA
#     - Comparing multiple dependent variables
#
#     5. ANCOVA
#     - Adjusting for external covariates
#
#     6. Mixed-Design ANOVA
#     - Combining independent groups and repeated measures
#
#
# 22. What is the F-test, and how does it relate to hypothesis testing
#
#    - What Is the F-Test?
#       - The F-test is a statistical test used to compare the variances or means of two or more groups to determine if they are significantly different. It is based on the F-distribution, which is always positive and right-skewed.
#
#    - When Is the F-Test Used?
#
#       - Comparing Variances
#       - Analysis of Variance (ANOVA)
#       - Regression Analysis

# %% [markdown]
# # PRACTICAL

# %%
# Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results

import scipy.stats as stats
import math

def z_test(sample_mean, population_mean, std_dev, sample_size, alpha=0.05, tail="two"):
    z_score = (sample_mean - population_mean) / (std_dev / math.sqrt(sample_size))


    if tail == "two":
        p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))
    elif tail == "left":
        p_value = stats.norm.cdf(z_score)
    elif tail == "right":
        p_value = 1 - stats.norm.cdf(z_score)
    else:
        raise ValueError("Invalid tail type. Choose 'two', 'left', or 'right'.")

    # Interpretation
    print(f"Z-Score: {z_score:.4f}")
    print(f"P-Value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis (H0). There is significant evidence.")
    else:
        print("Fail to reject the null hypothesis (H0). No significant difference.")

sample_mean = 52
population_mean = 50
std_dev = 5
sample_size = 30
alpha = 0.05
tail = "two"

z_test(sample_mean, population_mean, std_dev, sample_size, alpha, tail)
# Out:
# Z-Score: 2.1909
# P-Value: 0.0285
# Reject the null hypothesis (H0). There is significant evidence.

# %%
# Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python

import numpy as np
import scipy.stats as stats

np.random.seed(42)

sample_size = 30
population_mean = 50
population_std_dev = 10
sample = np.random.normal(loc=52, scale=10, size=sample_size)


sample_mean = np.mean(sample)
sample_std_dev = np.std(sample, ddof=1)

# Perform Z-test if population std dev is known, else use T-test
use_z_test = True  # Change to False to use T-test

if use_z_test:
    # Compute Z-score
    z_score = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))
    # Compute p-value (Two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))
    print(f"Using Z-Test:")
else:
    # Compute T-test
    t_score, p_value = stats.ttest_1samp(sample, population_mean)
    print(f"Using T-Test:")

# Print Results
print(f"Sample Mean: {sample_mean:.4f}")
print(f"Sample Std Dev: {sample_std_dev:.4f}")
print(f"Test Statistic: {z_score if use_z_test else t_score:.4f}")
print(f"P-Value: {p_value:.4f}")

# Interpret Results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis (H0): Significant difference detected.")
else:
    print("Fail to reject the null hypothesis (H0): No significant difference.")
# Out:
# Using Z-Test:
# Sample Mean: 50.1185
# Sample Std Dev: 9.0001
# Test Statistic: 0.0649
# P-Value: 0.9482
# Fail to reject the null hypothesis (H0): No significant difference.

# %%
# Implement a one-sample Z-test using Python to compare the sample mean with the population mean

import numpy as np
import scipy.stats as stats

def one_sample_z_test(sample, population_mean, population_std_dev, alpha=0.05, tail="two"):
    sample_size = len(sample)
    sample_mean = np.mean(sample)

    # Calculate Z-score
    z_score = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))

    # Calculate p-value
    if tail == "two":
        p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))  # Two-tailed test
    elif tail == "left":
        p_value = stats.norm.cdf(z_score)  # Left-tailed test
    elif tail == "right":
        p_value = 1 - stats.norm.cdf(z_score)  # Right-tailed test
    else:
        raise ValueError("Invalid tail type. Choose 'two', 'left', or 'right'.")

    # Print results
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-Score: {z_score:.4f}")
    print(f"P-Value: {p_value:.4f}")

    # Decision Rule
    if p_value < alpha:
        print("Reject the null hypothesis (H0): Significant difference detected.")
    else:
        print("Fail to reject the null hypothesis (H0): No significant difference.")

# Simulated sample data (normally distributed)
np.random.seed(42)
sample_data = np.random.normal(loc=52, scale=10, size=30)  # Sample mean ≠ Population mean

# Define known population parameters
population_mean = 50
population_std_dev = 10  # Known population standard deviation

# Perform the Z-test (two-tailed)
one_sample_z_test(sample_data, population_mean, population_std_dev, alpha=0.05, tail="two")
# Out:
# Sample Mean: 50.1185
# Z-Score: 0.0649
# P-Value: 0.9482
# Fail to reject the null hypothesis (H0): No significant difference.

# %%
# Perform a two-tailed Z-test using Python and visualize the decision region on a plot

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def two_tailed_z_test(sample, population_mean, population_std_dev, alpha=0.05):
    sample_size = len(sample)
    sample_mean = np.mean(sample)

    # Calculate Z-score
    z_score = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Critical value (for two-tailed test)
    critical_value = stats.norm.ppf(1 - alpha / 2)

    # Print results
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-Score: {z_score:.4f}")
    print(f"P-Value: {p_value:.4f}")
    print(f"Critical Z-Value: ±{critical_value:.4f}")

    # Decision Rule
    if abs(z_score) > critical_value:
        print("Reject the null hypothesis (H0): Significant difference detected.")
    else:
        print("Fail to reject the null hypothesis (H0): No significant difference.")

    # Visualization
    plot_z_test(z_score, critical_value)

def plot_z_test(z_score, critical_value):
    # Generate values for the normal distribution
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x, 0, 1)

    plt.figure(figsize=(10, 5))
    plt.plot(x, y, label="Standard Normal Distribution", color="blue")

    # Shade the rejection regions
    plt.fill_between(x, y, where=(x <= -critical_value) | (x >= critical_value), color='red', alpha=0.3, label="Rejection Region")

    # Plot the Z-score
    plt.axvline(z_score, color='black', linestyle='dashed', label=f"Z-Score = {z_score:.4f}")

    # Add labels
    plt.axvline(-critical_value, color='red', linestyle='dashed', label=f"Critical Value = ±{critical_value:.4f}")
    plt.axvline(critical_value, color='red', linestyle='dashed')

    plt.title("Two-Tailed Z-Test Visualization")
    plt.xlabel("Z-Score")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid()
    plt.show()

# Simulated sample data (normally distributed)
np.random.seed(42)
sample_data = np.random.normal(loc=52, scale=10, size=30)  # Sample with mean ≠ Population mean

# Define known population parameters
population_mean = 50
population_std_dev = 10  # Known population standard deviation

# Perform the two-tailed Z-test
two_tailed_z_test(sample_data, population_mean, population_std_dev, alpha=0.05)
# Out:
# Sample Mean: 50.1185
# Z-Score: 0.0649
# P-Value: 0.9482
# Critical Z-Value: ±1.9600
# Fail to reject the null hypothesis (H0): No significant difference.

# %%
# Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def visualize_type1_type2_errors(mu_null=50, mu_alt=53, sigma=10, sample_size=30, alpha=0.05):
    """
    Visualizes Type 1 and Type 2 errors in hypothesis testing.

    Parameters:
    - mu_null: Mean under H0
    - mu_alt: Mean under H1
    - sigma: Population standard deviation
    - sample_size: Size of the sample
    - alpha: Significance level (default = 0.05)
    """
    # Calculate standard error
    standard_error = sigma / np.sqrt(sample_size)

    # Compute critical value (for two-tailed test)
    z_critical = stats.norm.ppf(1 - alpha / 2)  # Two-tailed test
    critical_value = mu_null + z_critical * standard_error  # Right-tail critical value

    # Compute Type 2 error (Beta)
    beta = stats.norm.cdf((critical_value - mu_alt) / standard_error)
    power = 1 - beta  # Power of the test

    # Generate x values for the normal curves
    x = np.linspace(mu_null - 4 * standard_error, mu_alt + 4 * standard_error, 1000)
    y_null = stats.norm.pdf(x, mu_null, standard_error)
    y_alt = stats.norm.pdf(x, mu_alt, standard_error)

    # Plot the distributions
    plt.figure(figsize=(10, 5))
    plt.plot(x, y_null, label="H0: Null Distribution", color="blue")
    plt.plot(x, y_alt, label="H1: Alternative Distribution", color="green")

    # Shade Type 1 Error (Alpha)
    plt.fill_between(x, y_null, where=(x >= critical_value), color='red', alpha=0.3, label="Type 1 Error (α)")

    # Shade Type 2 Error (Beta)
    plt.fill_between(x, y_alt, where=(x < critical_value), color='purple', alpha=0.3, label="Type 2 Error (β)")

    # Mark critical value
    plt.axvline(critical_value, color='black', linestyle='dashed', label=f"Critical Value = {critical_value:.2f}")

    # Labels & Legends
    plt.title("Type 1 & Type 2 Errors in Hypothesis Testing")
    plt.xlabel("Sample Mean")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid()
    plt.show()

    # Print results
    print(f"Critical Value: {critical_value:.2f}")
    print(f"Type 1 Error (Alpha): {alpha}")
    print(f"Type 2 Error (Beta): {beta:.4f}")
    print(f"Power of the Test (1 - Beta): {power:.4f}")

# Run the function
visualize_type1_type2_errors(mu_null=50, mu_alt=53, sigma=10, sample_size=30, alpha=0.05)
# Out:
# Critical Value: 53.58
# Type 1 Error (Alpha): 0.05
# Type 2 Error (Beta): 0.6243
# Power of the Test (1 - Beta): 0.3757

# %%
# Write a Python program to perform an independent T-test and interpret the results

import numpy as np
import scipy.stats as stats

def independent_t_test(sample1, sample2, alpha=0.05, equal_var=True):
    """
    Performs an independent two-sample T-test.

    Parameters:
    - sample1: First sample (array-like)
    - sample2: Second sample (array-like)
    - alpha: Significance level (default = 0.05)
    - equal_var: Assumption of equal variances (default = True)

    Returns:
    - T-statistic, P-value, and interpretation
    """
    # Perform independent T-test
    t_stat, p_value = stats.ttest_ind(sample1, sample2, equal_var=equal_var)

    # Print results
    print(f"Sample 1 Mean: {np.mean(sample1):.4f}")
    print(f"Sample 2 Mean: {np.mean(sample2):.4f}")
    print(f"T-Statistic: {t_stat:.4f}")
    print(f"P-Value: {p_value:.4f}")

    # Decision Rule
    if p_value < alpha:
        print("Reject the null hypothesis (H0): Significant difference detected.")
    else:
        print("Fail to reject the null hypothesis (H0): No significant difference.")

# Simulate two independent samples (normally distributed)
np.random.seed(42)
sample1 = np.random.normal(loc=55, scale=10, size=30)  # Mean = 55, Std Dev = 10
sample2 = np.random.normal(loc=50, scale=10, size=30)  # Mean = 50, Std Dev = 10

# Perform the independent T-test
independent_t_test(sample1, sample2, alpha=0.05, equal_var=True)
# Out:
# Sample 1 Mean: 53.1185
# Sample 2 Mean: 48.7884
# T-Statistic: 1.8315
# P-Value: 0.0722
# Fail to reject the null hypothesis (H0): No significant difference.

# %%
# Perform a paired sample T-test using Python and visualize the comparison results

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def paired_t_test(before, after, alpha=0.05):
    """
    Performs a paired (dependent) T-test and visualizes the results.

    Parameters:
    - before: Data before treatment (array-like)
    - after: Data after treatment (array-like)
    - alpha: Significance level (default = 0.05)
    """
    # Perform Paired T-test
    t_stat, p_value = stats.ttest_rel(before, after)

    # Print results
    print(f"Mean Before: {np.mean(before):.4f}")
    print(f"Mean After: {np.mean(after):.4f}")
    print(f"T-Statistic: {t_stat:.4f}")
    print(f"P-Value: {p_value:.4f}")

    # Decision Rule
    if p_value < alpha:
        print("Reject the null hypothesis (H0): Significant difference detected.")
    else:
        print("Fail to reject the null hypothesis (H0): No significant difference.")

    # Visualization
    plot_paired_t_test(before, after)

def plot_paired_t_test(before, after):
    """
    Plots the before and after results for visual comparison.
    """
    plt.figure(figsize=(8, 5))

    # Create scatter plot
    plt.scatter(np.arange(len(before)), before, color='blue', label="Before", alpha=0.7)
    plt.scatter(np.arange(len(after)), after, color='green', label="After", alpha=0.7)

    # Draw lines connecting paired values
    for i in range(len(before)):
        plt.plot([i, i], [before[i], after[i]], color='gray', linestyle='dotted')

    # Labels & Titles
    plt.title("Paired Sample T-Test Comparison")
    plt.xlabel("Subject Index")
    plt.ylabel("Measurement Value")
    plt.legend()
    plt.grid()
    plt.show()

# Simulated data: Scores before & after training
np.random.seed(42)
before_scores = np.random.normal(loc=50, scale=10, size=30)  # Before treatment
after_scores = before_scores + np.random.normal(loc=3, scale=5, size=30)  # After treatment

# Perform Paired T-test
paired_t_test(before_scores, after_scores, alpha=0.05)
# Out:
# Mean Before: 48.1185
# Mean After: 50.5127
# T-Statistic: -2.8168
# P-Value: 0.0086
# Reject the null hypothesis (H0): Significant difference detected.

# %%
# Simulate data and perform both Z-test and T-test, then compare the results using Python

import numpy as np
import scipy.stats as stats

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Performs a one-sample Z-test.

    Parameters:
    - sample: Sample data (array-like)
    - pop_mean: Population mean
    - pop_std: Population standard deviation
    - alpha: Significance level (default = 0.05)
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Compute Z-score
    z_score = (sample_mean - pop_mean) / standard_error
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))  # Two-tailed test

    # Print results
    print("\n=== Z-Test Results ===")
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-Score: {z_score:.4f}")
    print(f"P-Value: {p_value:.4f}")

    # Decision Rule
    if p_value < alpha:
        print("Reject the null hypothesis (H0): Significant difference detected.")
    else:
        print("Fail to reject the null hypothesis (H0): No significant difference.")

def t_test(sample, pop_mean, alpha=0.05):
    """
    Performs a one-sample T-test.

    Parameters:
    - sample: Sample data (array-like)
    - pop_mean: Population mean
    - alpha: Significance level (default = 0.05)
    """
    t_stat, p_value = stats.ttest_1samp(sample, pop_mean)

    # Print results
    print("\n=== T-Test Results ===")
    print(f"Sample Mean: {np.mean(sample):.4f}")
    print(f"T-Statistic: {t_stat:.4f}")
    print(f"P-Value: {p_value:.4f}")

    # Decision Rule
    if p_value < alpha:
        print("Reject the null hypothesis (H0): Significant difference detected.")
    else:
        print("Fail to reject the null hypothesis (H0): No significant difference.")

# Simulating random sample data
np.random.seed(42)
sample_size = 30  # Small sample size for T-test
pop_mean = 50     # Population mean
pop_std = 10      # Known population standard deviation

# Generate sample data (normally distributed)
sample_data = np.random.normal(loc=52, scale=pop_std, size=sample_size)

# Perform both tests
z_test(sample_data, pop_mean, pop_std, alpha=0.05)
t_test(sample_data, pop_mean, alpha=0.05)
# Out:
# === Z-Test Results ===
# Sample Mean: 50.1185
# Z-Score: 0.0649
# P-Value: 0.9482
# Fail to reject the null hypothesis (H0): No significant difference.
#
# === T-Test Results ===
# Sample Mean: 50.1185
# T-Statistic: 0.0721
# P-Value: 0.9430
# Fail to reject the null hypothesis (H0): No significant difference.

# %%
# Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

import numpy as np
import scipy.stats as stats

def confidence_interval(sample, confidence=0.95):
    """
    Calculates the confidence interval for a sample mean.

    Parameters:
    - sample: Sample data (array-like)
    - confidence: Confidence level (default = 0.95)

    Returns:
    - Lower bound, Upper bound of the confidence interval
    """
    sample_mean = np.mean(sample)  # Sample mean
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation (ddof=1 for sample)
    n = len(sample)  # Sample size

    # Compute margin of error using t-distribution (for small sample sizes)
    t_score = stats.t.ppf((1 + confidence) / 2, df=n-1)  # Two-tailed test
    margin_of_error = t_score * (sample_std / np.sqrt(n))

    # Confidence interval bounds
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

# Simulated Sample Data
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=30)  # Sample with mean=50, std=10

# Calculate 95% Confidence Interval
ci_lower, ci_upper = confidence_interval(sample_data, confidence=0.95)

# Print the result
print(f"95% Confidence Interval: ({ci_lower:.4f}, {ci_upper:.4f})")
# Out:
# 95% Confidence Interval: (44.7579, 51.4792)

# %%
# Write a Python program to calculate the margin of error for a given confidence level using sample data

import numpy as np
import scipy.stats as stats

def margin_of_error(sample, confidence=0.95):
    """
    Calculates the margin of error for a given confidence level.

    Parameters:
    - sample: Sample data (array-like)
    - confidence: Confidence level (default = 0.95)

    Returns:
    - Margin of error
    """
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation (ddof=1 for sample)
    n = len(sample)  # Sample size

    # Get the critical value from the t-distribution
    t_score = stats.t.ppf((1 + confidence) / 2, df=n-1)

    # Compute margin of error
    moe = t_score * (sample_std / np.sqrt(n))

    return moe

# Simulated Sample Data
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=30)  # Sample with mean=50, std=10

# Calculate Margin of Error for 95% Confidence Level
moe_95 = margin_of_error(sample_data, confidence=0.95)

# Print the result
print(f"Margin of Error (95% Confidence Level): {moe_95:.4f}")
# Out:
# Margin of Error (95% Confidence Level): 3.3607

# %%
# Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

def bayes_theorem(prior_A, likelihood_B_given_A, likelihood_B_given_not_A):
    """
    Computes the posterior probability using Bayes' Theorem.

    Parameters:
    - prior_A: P(A) - Prior probability of event A
    - likelihood_B_given_A: P(B | A) - Likelihood of B given A
    - likelihood_B_given_not_A: P(B | ¬A) - Likelihood of B given not A

    Returns:
    - Posterior probability P(A | B)
    """
    # Total probability of B
    prior_not_A = 1 - prior_A  # Complement of prior A
    P_B = (likelihood_B_given_A * prior_A) + (likelihood_B_given_not_A * prior_not_A)

    # Apply Bayes' Theorem
    posterior_A_given_B = (likelihood_B_given_A * prior_A) / P_B

    return posterior_A_given_B

# Example Scenario: Disease Testing
prior_disease = 0.01  # 1% of the population has the disease
test_sensitivity = 0.95  # P(Positive Test | Disease) = 95% (True Positive Rate)
test_false_positive = 0.05  # P(Positive Test | No Disease) = 5% (False Positive Rate)

# Compute posterior probability of having the disease given a positive test
posterior_disease_given_positive = bayes_theorem(prior_disease, test_sensitivity, test_false_positive)

# Print results
print(f"Probability of having the disease given a positive test result: {posterior_disease_given_positive:.4f}")
# Out:
# Probability of having the disease given a positive test result: 0.1610

# %%
# Perform a Chi-square test for independence between two categorical variables in Python

import numpy as np
import scipy.stats as stats
import pandas as pd

# Create a contingency table (Example: Survey on Gender vs. Preference for a Product)
data = np.array([[30, 10],  # Male: 30 prefer, 10 don't prefer
                 [25, 15]]) # Female: 25 prefer, 15 don't prefer

# Convert to DataFrame for better visualization
df = pd.DataFrame(data, columns=["Prefer", "Don't Prefer"], index=["Male", "Female"])
print("Contingency Table:\n", df)

# Perform Chi-Square Test for Independence
chi2_stat, p_value, dof, expected = stats.chi2_contingency(df)

# Print results
print("\n=== Chi-Square Test Results ===")
print(f"Chi-Square Statistic: {chi2_stat:.4f}")
print(f"P-Value: {p_value:.4f}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies:\n", pd.DataFrame(expected, columns=df.columns, index=df.index))

# Decision Rule at α = 0.05
alpha = 0.05
if p_value < alpha:
    print("\nReject the null hypothesis (H0): The variables are dependent (significant relationship).")
else:
    print("\nFail to reject the null hypothesis (H0): No significant relationship between the variables.")
# Out:
# Contingency Table:
#          Prefer  Don't Prefer
# Male        30            10
# Female      25            15
#
# === Chi-Square Test Results ===
# Chi-Square Statistic: 0.9309
# P-Value: 0.3346
# Degrees of Freedom: 1
# Expected Frequencies:
#          Prefer  Don't Prefer
# Male      27.5          12.5
# Female    27.5          12.5
#
# Fail to reject the null hypothesis (H0): No significant relationship between the variables.

# %%
# Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution

import numpy as np
import scipy.stats as stats

# Observed frequencies (e.g., Survey responses)
observed = np.array([50, 30, 20])  # Categories: A, B, C

# Expected frequencies assuming equal distribution
expected = np.array([33.33, 33.33, 33.33])

# Perform Chi-Square Goodness-of-Fit Test
chi2_stat, p_value = stats.chisquare(f_obs=observed, f_exp=expected)

# Print results
print("=== Chi-Square Goodness-of-Fit Test ===")
print(f"Chi-Square Statistic: {chi2_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# Decision Rule at α = 0.05
alpha = 0.05
if p_value < alpha:
    print("\nReject the null hypothesis (H0): The observed data does not follow the expected distribution.")
else:
    print("\nFail to reject the null hypothesis (H0): The observed data follows the expected distribution.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-68817fc3800e> in <cell line: 0>()
#      11
#      12 # Perform Chi-Square Goodness-of-Fit Test
# ---> 13 chi2_stat, p_value = stats.chisquare(f_obs=observed, f_exp=expected)
#      14
#      15 # Print results
#
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_stats_py.py in chisquare(f_obs, f_exp, ddof, axis)
#    7848
#    7849     """  # noqa: E501
# -> 7850     return power_divergence(f_obs, f_exp=f_exp, ddof=ddof, axis=axis,
#    7851                             lambda_="pearson")
#    7852
#
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_stats_py.py in power_divergence(f_obs, f_exp, ddof, axis, lambda_)
#    7639                    f"of {rtol}, but the percent differences are:\n"
#    7640                    f"{relative_diff}")
# -> 7641             raise ValueError(msg)
#    7642
# ...

# %%
# Implement an F-test using Python to compare the variances of two random samples

import numpy as np
import scipy.stats as stats

# Generate two random samples
np.random.seed(42)
sample1 = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std=10
sample2 = np.random.normal(loc=50, scale=15, size=30)  # Mean=50, Std=15

# Compute sample variances
var1 = np.var(sample1, ddof=1)
var2 = np.var(sample2, ddof=1)

# Compute F-statistic
F_stat = var1 / var2 if var1 > var2 else var2 / var1  # Ensure F > 1

# Degrees of freedom
df1 = len(sample1) - 1
df2 = len(sample2) - 1

# Compute p-value
p_value = 2 * (1 - stats.f.cdf(F_stat, df1, df2))  # Two-tailed test

# Print results
print("=== F-Test for Equality of Variances ===")
print(f"Sample 1 Variance: {var1:.4f}")
print(f"Sample 2 Variance: {var2:.4f}")
print(f"F-Statistic: {F_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# Decision Rule at α = 0.05
alpha = 0.05
if p_value < alpha:
    print("\nReject the null hypothesis (H0): The variances are significantly different.")
else:
    print("\nFail to reject the null hypothesis (H0): No significant difference in variances.")
# Out:
# === F-Test for Equality of Variances ===
# Sample 1 Variance: 81.0012
# Sample 2 Variance: 195.0640
# F-Statistic: 2.4082
# P-Value: 0.0209
#
# Reject the null hypothesis (H0): The variances are significantly different.

# %%
#  Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the resultsD

import numpy as np
import scipy.stats as stats

# Generate random sample data for three groups
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std=10
group2 = np.random.normal(loc=55, scale=10, size=30)  # Mean=55, Std=10
group3 = np.random.normal(loc=60, scale=10, size=30)  # Mean=60, Std=10

# Perform One-Way ANOVA
F_stat, p_value = stats.f_oneway(group1, group2, group3)

# Print results
print("=== One-Way ANOVA Test ===")
print(f"F-Statistic: {F_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# Decision Rule at α = 0.05
alpha = 0.05
if p_value < alpha:
    print("\nReject the null hypothesis (H0): At least one group mean is significantly different.")
else:
    print("\nFail to reject the null hypothesis (H0): No significant difference between group means.")

# %%
#  Perform a one-way ANOVA test using Python to compare the means of different groups and plot the resultsimport numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Generate random sample data for three groups
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std=10
group2 = np.random.normal(loc=55, scale=10, size=30)  # Mean=55, Std=10
group3 = np.random.normal(loc=60, scale=10, size=30)  # Mean=60, Std=10

# Perform One-Way ANOVA
F_stat, p_value = stats.f_oneway(group1, group2, group3)

# Print results
print("=== One-Way ANOVA Test ===")
print(f"F-Statistic: {F_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# Decision Rule at α = 0.05
alpha = 0.05
if p_value < alpha:
    print("\nReject the null hypothesis (H0): At least one group mean is significantly different.")
else:
    print("\nFail to reject the null hypothesis (H0): No significant difference between group means.")

# Convert data to Pandas DataFrame for visualization
data = {
    "Value": np.concatenate([group1, group2, group3]),
    "Group": ["Group 1"] * 30 + ["Group 2"] * 30 + ["Group 3"] * 30
}
df = pd.DataFrame(data)

# Visualization: Boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x="Group", y="Value", data=df, palette="Set2")
plt.title("One-Way ANOVA: Comparison of Group Means")
plt.xlabel("Groups")
plt.ylabel("Values")
plt.grid(True)
plt.show()
# Out:
# === One-Way ANOVA Test ===
# F-Statistic: 12.2095
# P-Value: 0.0000
#
# Reject the null hypothesis (H0): At least one group mean is significantly different.
# <ipython-input-15-aa8ea9a576ba>:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Group", y="Value", data=df, palette="Set2")

# %%
# Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results

import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Generate sample data
np.random.seed(42)
size = 30  # Number of observations per group

# Factor 1: Treatment (A1, A2)
# Factor 2: Diet (B1, B2)
A = np.repeat(["A1", "A2"], size * 2)
B = np.tile(["B1", "B2"], size * 2)

# Response Variable: Random values with different means
values = np.concatenate([
    np.random.normal(loc=50, scale=10, size=size),  # A1B1
    np.random.normal(loc=55, scale=10, size=size),  # A1B2
    np.random.normal(loc=52, scale=10, size=size),  # A2B1
    np.random.normal(loc=60, scale=10, size=size)   # A2B2
])

# Create DataFrame
df = pd.DataFrame({"Treatment": A, "Diet": B, "Value": values})

# Fit Two-Way ANOVA model
model = ols("Value ~ C(Treatment) + C(Diet) + C(Treatment):C(Diet)", data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# Print ANOVA results
print("=== Two-Way ANOVA Test Results ===")
print(anova_table)

# Decision rule (α = 0.05)
alpha = 0.05
for factor in anova_table.index:
    p_value = anova_table.loc[factor, "PR(>F)"]
    if p_value < alpha:
        print(f"\nReject H0 for {factor}: Significant effect found.")
    else:
        print(f"\nFail to reject H0 for {factor}: No significant effect.")

# Visualization: Interaction Plot
plt.figure(figsize=(8, 6))
sns.pointplot(data=df, x="Treatment", y="Value", hue="Diet", palette="Set1", capsize=0.1)
plt.title("Two-Way ANOVA: Interaction Effect of Treatment & Diet")
plt.xlabel("Treatment")
plt.ylabel("Mean Value")
plt.grid(True)
plt.show()
# Out:
# === Two-Way ANOVA Test Results ===
#                             sum_sq     df         F    PR(>F)
# C(Treatment)            752.916598    1.0  7.652459  0.006599
# C(Diet)                  25.246185    1.0  0.256596  0.613430
# C(Treatment):C(Diet)     38.130722    1.0  0.387551  0.534811
# Residual              11413.106235  116.0       NaN       NaN
#
# Reject H0 for C(Treatment): Significant effect found.
#
# Fail to reject H0 for C(Diet): No significant effect.
#
# Fail to reject H0 for C(Treatment):C(Diet): No significant effect.
#
# Fail to reject H0 for Residual: No significant effect.

# %%
# Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Define degrees of freedom for different F-distributions
df1_values = [1, 5, 10]
df2 = 20  # Fixed denominator degrees of freedom
x = np.linspace(0, 5, 1000)  # Range of F-values

# Plot F-distributions for different numerator degrees of freedom
plt.figure(figsize=(8, 6))
for df1 in df1_values:
    f_dist = stats.f.pdf(x, df1, df2)  # Compute Probability Density Function (PDF)
    plt.plot(x, f_dist, label=f"df1={df1}, df2={df2}")

# Critical region (α = 0.05, one-tailed test)
alpha = 0.05
f_critical = stats.f.ppf(1 - alpha, df1_values[-1], df2)  # Critical F-value for largest df1
plt.axvline(f_critical, color='red', linestyle='dashed', label=f"Critical Value (α=0.05)")

# Plot settings
plt.title("F-Distribution for Different Degrees of Freedom")
plt.xlabel("F-value")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()

# %%
#  Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means

import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

# Generate sample data for 3 groups
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std=10
group2 = np.random.normal(loc=55, scale=10, size=30)  # Mean=55, Std=10
group3 = np.random.normal(loc=60, scale=10, size=30)  # Mean=60, Std=10

# Create a DataFrame
df = pd.DataFrame({
    "Group": ["A"] * 30 + ["B"] * 30 + ["C"] * 30,
    "Value": np.concatenate([group1, group2, group3])
})

# Perform One-Way ANOVA
f_stat, p_value = stats.f_oneway(group1, group2, group3)

# Print ANOVA test results
print("=== One-Way ANOVA Test ===")
print(f"F-Statistic: {f_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# Decision Rule (α = 0.05)
alpha = 0.05
if p_value < alpha:
    print("\nReject H0: Significant difference exists between group means.")
else:
    print("\nFail to reject H0: No significant difference between group means.")

# Visualization: Boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x="Group", y="Value", data=df, palette="Set2")
plt.title("One-Way ANOVA: Group Mean Comparisons")
plt.xlabel("Groups")
plt.ylabel("Values")
plt.grid(True)
plt.show()
# Out:
# === One-Way ANOVA Test ===
# F-Statistic: 12.2095
# P-Value: 0.0000
#
# Reject H0: Significant difference exists between group means.
# <ipython-input-18-39aa68b5463c>:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Group", y="Value", data=df, palette="Set2")

# %%
# Perform a hypothesis test for population variance using a Chi-square distribution and interpret the resultsD

import numpy as np
import scipy.stats as stats

# Sample data (randomly generated)
np.random.seed(42)
sample = np.random.normal(loc=50, scale=5, size=30)  # Mean=50, Std=5, Size=30

# Given hypothesized population variance
sigma0_squared = 25  # Hypothesized variance (σ0^2 = 5^2)

# Sample statistics
n = len(sample)  # Sample size
sample_variance = np.var(sample, ddof=1)  # Sample variance (unbiased estimator)

# Chi-Square Test Statistic
chi_square_stat = (n - 1) * sample_variance / sigma0_squared

# Degrees of freedom
df = n - 1

# Compute p-value (two-tailed test)
p_value = 2 * min(stats.chi2.cdf(chi_square_stat, df), 1 - stats.chi2.cdf(chi_square_stat, df))

# Print Results
print("=== Chi-Square Test for Population Variance ===")
print(f"Sample Variance: {sample_variance:.4f}")
print(f"Chi-Square Statistic: {chi_square_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# Decision Rule (α = 0.05)
alpha = 0.05
if p_value < alpha:
    print("\nReject H0: The population variance is significantly different from the hypothesized variance.")
else:
    print("\nFail to reject H0: No significant difference in population variance.")
# Out:
# === Chi-Square Test for Population Variance ===
# Sample Variance: 20.2503
# Chi-Square Statistic: 23.4903
# P-Value: 0.4927
#
# Fail to reject H0: No significant difference in population variance.

# %%
# Write a Python script to perform a Z-test for comparing proportions between two datasets or groups

import numpy as np
import scipy.stats as stats

def z_test_proportions(x1, n1, x2, n2, alpha=0.05):
    """
    Perform a two-proportion Z-test.

    Parameters:
    x1, x2: Number of successes in each group
    n1, n2: Sample sizes of each group
    alpha: Significance level (default = 0.05)

    Returns:
    Z-score, p-value, and conclusion
    """
    # Sample proportions
    p1 = x1 / n1
    p2 = x2 / n2

    # Pooled proportion
    p = (x1 + x2) / (n1 + n2)

    # Standard error
    se = np.sqrt(p * (1 - p) * (1/n1 + 1/n2))

    # Z-score calculation
    z_score = (p1 - p2) / se

    # P-value for two-tailed test
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Critical Z-value for two-tailed test
    z_critical = stats.norm.ppf(1 - alpha/2)

    # Print results
    print("=== Two-Proportion Z-Test ===")
    print(f"Sample Proportions: p1 = {p1:.4f}, p2 = {p2:.4f}")
    print(f"Pooled Proportion: {p:.4f}")
    print(f"Z-Score: {z_score:.4f}")
    print(f"P-Value: {p_value:.4f}")
    print(f"Critical Z-Value: ±{z_critical:.4f}")

    # Decision Rule
    if abs(z_score) > z_critical or p_value < alpha:
        print("\nReject H0: Significant difference between proportions.")
    else:
        print("\nFail to reject H0: No significant difference between proportions.")

# Example Data: Two groups with different success rates
x1, n1 = 180, 400  # Group 1: 180 successes out of 400
x2, n2 = 150, 400  # Group 2: 150 successes out of 400

# Run Z-Test for proportions
z_test_proportions(x1, n1, x2, n2)
# Out:
# === Two-Proportion Z-Test ===
# Sample Proportions: p1 = 0.4500, p2 = 0.3750
# Pooled Proportion: 0.4125
# Z-Score: 2.1546
# P-Value: 0.0312
# Critical Z-Value: ±1.9600
#
# Reject H0: Significant difference between proportions.

# %%
# Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Generate random datasets
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std=10, Size=30
group2 = np.random.normal(loc=52, scale=15, size=30)  # Mean=52, Std=15, Size=30

# Compute sample variances
s1_squared = np.var(group1, ddof=1)  # Sample variance (unbiased)
s2_squared = np.var(group2, ddof=1)

# Assign larger variance to the numerator
if s1_squared > s2_squared:
    F_stat = s1_squared / s2_squared
    df1, df2 = len(group1) - 1, len(group2) - 1
else:
    F_stat = s2_squared / s1_squared
    df1, df2 = len(group2) - 1, len(group1) - 1

# Compute p-value (two-tailed test)
p_value = 2 * min(stats.f.cdf(F_stat, df1, df2), 1 - stats.f.cdf(F_stat, df1, df2))

# Print results
print("=== F-Test for Equality of Variances ===")
print(f"Sample Variances: Group1 = {s1_squared:.4f}, Group2 = {s2_squared:.4f}")
print(f"F-Statistic: {F_stat:.4f}")
print(f"Degrees of Freedom: df1 = {df1}, df2 = {df2}")
print(f"P-Value: {p_value:.4f}")

# Decision Rule (α = 0.05)
alpha = 0.05
if p_value < alpha:
    print("\nReject H0: Significant difference in variances.")
else:
    print("\nFail to reject H0: No significant difference in variances.")

# Visualization of the F-Distribution
x = np.linspace(0, 5, 1000)
y = stats.f.pdf(x, df1, df2)

plt.figure(figsize=(8, 5))
plt.plot(x, y, label=f"F-Distribution (df1={df1}, df2={df2})")
plt.axvline(F_stat, color='r', linestyle='--', label=f'F-Statistic = {F_stat:.2f}')
plt.fill_between(x, y, where=(x > stats.f.ppf(1-alpha/2, df1, df2)) | (x < stats.f.ppf(alpha/2, df1, df2)),
                 color='red', alpha=0.3, label='Rejection Regions (α=0.05)')
plt.xlabel("F-Value")
plt.ylabel("Density")
plt.title("F-Test: Variance Comparison")
plt.legend()
plt.show()
# Out:
# === F-Test for Equality of Variances ===
# Sample Variances: Group1 = 81.0012, Group2 = 195.0640
# F-Statistic: 2.4082
# Degrees of Freedom: df1 = 29, df2 = 29
# P-Value: 0.0209
#
# Reject H0: Significant difference in variances.

# %%
# Perform a Chi-square test for goodness of fit with simulated data and analyze the results.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Simulated observed data (e.g., survey results of preferences among 4 categories)
observed = np.array([50, 30, 20, 100])

# Expected data assuming uniform distribution (equal preference)
expected = np.array([50, 50, 50, 50])

# Perform the Chi-square goodness of fit test
chi2_stat, p_value = stats.chisquare(f_obs=observed, f_exp=expected)

# Degrees of freedom = (number of categories - 1)
df = len(observed) - 1
critical_value = stats.chi2.ppf(0.95, df)  # For α = 0.05

# Print results
print("=== Chi-Square Goodness of Fit Test ===")
print(f"Observed Values: {observed}")
print(f"Expected Values: {expected}")
print(f"Chi-Square Statistic: {chi2_stat:.4f}")
print(f"Degrees of Freedom: {df}")
print(f"P-Value: {p_value:.4f}")
print(f"Critical Value (α=0.05): {critical_value:.4f}")

# Decision Rule
if chi2_stat > critical_value or p_value < 0.05:
    print("\nReject H0: The observed distribution does NOT match the expected distribution.")
else:
    print("\nFail to reject H0: The observed distribution matches the expected distribution.")

# Visualization of Observed vs Expected Frequencies
categories = ['A', 'B', 'C', 'D']
x = np.arange(len(categories))

plt.figure(figsize=(8, 5))
plt.bar(x - 0.2, observed, width=0.4, label="Observed", color='blue', alpha=0.7)
plt.bar(x + 0.2, expected, width=0.4, label="Expected", color='orange', alpha=0.7)
plt.xticks(x, categories)
plt.ylabel("Frequency")
plt.title("Chi-Square Goodness of Fit: Observed vs Expected")
plt.legend()
plt.show()
# Out:
# === Chi-Square Goodness of Fit Test ===
# Observed Values: [ 50  30  20 100]
# Expected Values: [50 50 50 50]
# Chi-Square Statistic: 76.0000
# Degrees of Freedom: 3
# P-Value: 0.0000
# Critical Value (α=0.05): 7.8147
#
# Reject H0: The observed distribution does NOT match the expected distribution.
